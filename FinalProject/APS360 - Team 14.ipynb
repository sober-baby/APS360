# %%
#Baseline modeling Roough work - helias work
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
#from sklearn.ensemble import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

data = np.loadtxt ('house.csv', d=',', row=1)
#split data into input feature but I am too ttired but ill assume we have targeted variable price as last column
x= data[:,:-1]
y = data[:,-1]

model = RandomForestRegressor()

x_train, x_test, y_train, y_test = train_test_split (x,y, size = 0.15, ) #I got really stuck on this part HELP, not sure what else to after size

model.fit(x_train,y_train)
prediction_test = model.predict(x_train)
mse = mean_squared_error(y_test, prediction_test)
rmse = 0.5**mse
print('rmse:',rmse)

plt.scaatter(y_test, prediction_test, color = 'red')
plt.plot([min(y_test), max(y_test), min(y_test), max(ytest)], color='green')
plt.ylaabel ('price prediction')
plt.xlabel ('actual price')
plt.title('actual price vs prediction price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-3bfb482fb124> in <cell line: 9>()
#       7 import numpy as np
#       8
# ----> 9 data = np.loadtxt ('house.csv', d= ',', row= 1)
#      10 #split data into input feature but I am too ttired but ill assume we have targeted variable price as last column
#      11 x= data[:,:-1]
#
# TypeError: loadtxt() got an unexpected keyword argument 'd'

# %%
#### LOADING CSV FILES INTO COLAB ####
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

file_id = 'https://drive.google.com/file/d/1zPiqrN9pRCtodbHS8UQevWXWlVK7vqZO/view?usp=share_link'
link = f'https://drive.google.com/uc?id={file_id}'
df = pd.read_csv(link)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-14-b38f482b7ae8> in <cell line: 5>()
#       3 file_id = 'https://drive.google.com/file/d/1zPiqrN9pRCtodbHS8UQevWXWlVK7vqZO/view?usp=share_link'
#       4 link = f'https://drive.google.com/uc?id={file_id}'
# ----> 5 df = pd.read_csv(link)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
# functions needed (copied from lab3)
import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import os
import PIL
from PIL import Image
import urllib.request
import tensorflow as tf
import shutil

# %%
# load the data from google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# mse baseline model from chatgpt
class MeanBaselineModel:
    def __init__(self):
        self.mean_value = None

    def fit(self, X, y):
        self.mean_value = np.mean(y)

    def predict(self, X):
        num_samples = X.shape[0]
        return np.full((num_samples,), self.mean_value)

    def evaluate(self, y_true, y_pred):
        return np.mean((y_true - y_pred) ** 2)

# %%
# Random Forest baseline from Tutorial 0 -- feel like sth like this should be what we are using
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=250)

# Fit the model to our training data
model.fit(training_data, training_labels)

# Make predictions
testing_predicted = model.predict(testing_data)
score = 100*(1-sum(abs(testing_predicted-testing_labels))/len(testing_predicted))
print("RF Test:", score)

# %%
# CNN model for numerical data from chat gpt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense

# Assuming you have input features X_train and corresponding target values y_train

# Reshape the input data
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)

# Create the CNN model
model = Sequential()
model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1))  # Output layer

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Assuming you have input features X_test for testing
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Make predictions
predictions = model.predict(X_test)

# Note: You'll need to evaluate the predictions based on your specific task and metrics.
